# %%
from __future__ import print_function
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.4955, 0.7938, 0.1337],
#         [0.8279, 0.2580, 0.2088],
#         [0.5817, 0.6603, 0.5019],
#         [0.7192, 0.7186, 0.3843],
#         [0.3697, 0.1866, 0.1893]])

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
import torch

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/8/Desktop/프로젝트/자율성장인공지능/토큰분리미적용/ddata.txt",encoding ='CP949',error_bad_lines=False,header=None,delimiter = '\t')

# %%
df
# Out:
#            0     1                                2  \
# 0        0.0  <CO>       어서오세요. 코디봇입니다. 무엇을 도와드릴까요?
# 1        1.0  <US>        처음 대학교 들어가는데 입을 옷 코디해주세요.
# 2        2.0  <CO>   신입생 코디에 어울리게 화사한 스웨터를 추천해드릴게요.
# 3        3.0  <AC>                           SW-009
# 4        4.0  <US>            이 옷에 어울리는 치마로 추천해주세요.
# ...      ...   ...                              ...
# 154672  15.0  <AC>             CT-022 SE-080 OP-051
# 154673  16.0  <CO>         선택하신 최종 코디입니다. 마음에 드시나요?
# 154674  17.0  <US>              네. 사진에도 잘 나올 것 같아요.
# 154675  18.0  <CO>                  마음에 드신다니 다행입니다.
# 154676  19.0  <CO>        이용해주셔서 감사합니다. 코디봇을 종료합니다.
#
#                                             3
# 0                                       INTRO
# 1                                         NaN
# 2       EXP_RES_SITUATION;EXP_RES_DESCRIPTION
# 3                                         NaN
# 4                                USER_SUCCESS
# ...                                       ...
# ...

# %%
df.columns=["num", "who", "question","label"]

# %%
df1 = df['who'] == '<US>'

# %%
df2 = df[df1]

# %%
df2
# Out:
#          num   who                                         question  \
# 1        1.0  <US>                        처음 대학교 들어가는데 입을 옷 코디해주세요.
# 4        4.0  <US>                            이 옷에 어울리는 치마로 추천해주세요.
# 7        7.0  <US>                         제가 키가 작아서 짧은 치마로 추천해주세요.
# 10      10.0  <US>                                     어두운 계열은 없나요?
# 13      13.0  <US>                           나쁘지 않네요. 외투도 추천해주시겠어요?
# ...      ...   ...                                              ...
# 154662   5.0  <US>  자켓말고 긴 가디건이나 얇은 트렌치코트 같은 걸로 바꿔주세요. 구두는 마음에 들어요.
# 154664   7.0  <US>                        원피스랑 잘 어울리는 색이면 좋을 것 같아요.
# 154668  11.0  <US>                                      너무 캐주얼해보여요.
# 154671  14.0  <US>                                    제가 찾던 스타일이에요.
# 154674  17.0  <US>                              네. 사진에도 잘 나올 것 같아요.
#
#                     label
# 1                     NaN
# 4            USER_SUCCESS
# 7               USER_FAIL
# 10              USER_FAIL
# ...

# %%
df3 = df2['label'] != 'USER_SUCCESS'

# %%
last = df2[df3]

# %%
last
# Out:
#          num   who                                         question  \
# 1        1.0  <US>                        처음 대학교 들어가는데 입을 옷 코디해주세요.
# 7        7.0  <US>                         제가 키가 작아서 짧은 치마로 추천해주세요.
# 10      10.0  <US>                                     어두운 계열은 없나요?
# 15      15.0  <US>                                트렌치코트 종류로 추천해주세요.
# 20      20.0  <US>                                     운동화로 추천해주세요.
# ...      ...   ...                                              ...
# 154647   9.0  <US>                                          딱히 없어요.
# 154658   1.0  <US>     꽃축제에 가족들이랑 가려고 하는데 원피스와 어울리는 화사한 코디를 추천해주세요.
# 154662   5.0  <US>  자켓말고 긴 가디건이나 얇은 트렌치코트 같은 걸로 바꿔주세요. 구두는 마음에 들어요.
# 154664   7.0  <US>                        원피스랑 잘 어울리는 색이면 좋을 것 같아요.
# 154668  11.0  <US>                                      너무 캐주얼해보여요.
#
#                     label
# 1                     NaN
# 7               USER_FAIL
# 10              USER_FAIL
# 15                    NaN
# ...

# %%
del last['num']
del last['who']

# %%
last
# Out:
#                                                question              label
# 1                             처음 대학교 들어가는데 입을 옷 코디해주세요.                NaN
# 7                              제가 키가 작아서 짧은 치마로 추천해주세요.          USER_FAIL
# 10                                         어두운 계열은 없나요?          USER_FAIL
# 15                                    트렌치코트 종류로 추천해주세요.                NaN
# 20                                         운동화로 추천해주세요.                NaN
# ...                                                 ...                ...
# 154647                                          딱히 없어요.                NaN
# 154658     꽃축제에 가족들이랑 가려고 하는데 원피스와 어울리는 화사한 코디를 추천해주세요.                NaN
# 154662  자켓말고 긴 가디건이나 얇은 트렌치코트 같은 걸로 바꿔주세요. 구두는 마음에 들어요.  USER_SUCCESS_PART
# 154664                        원피스랑 잘 어울리는 색이면 좋을 것 같아요.                NaN
# 154668                                      너무 캐주얼해보여요.          USER_FAIL
#
# [38979 rows x 2 columns]

# %%
last.to_csv('question.csv',sep=',',encoding='euc-kr')

# %%
df_w = pd.read_csv("D:/Workspace/Project_fashion/kochatt/data/raw/weather.csv",encoding ='CP949',error_bad_lines=False,header=None,delimiter = '\t')

# %%
df_t = pd.read_csv("D:/Workspace/Project_fashion/kochatt/data/raw/travel.csv",encoding ='CP949',error_bad_lines=False,header=None,delimiter = '\t')

# %%
df_o = pd.read_csv("D:/Workspace/Project_fashion/kochatt/data/raw/ood.csv",encoding ='CP949',error_bad_lines=False,header=None,delimiter = '\t')

# %%
df_w.to_csv('weather.csv',sep=',',encoding='euc-kr')

# %%
df_t.to_csv('travel.csv',sep=',',encoding='euc-kr')

# %%
df_o.to_csv('ood.csv',sep=',',encoding='euc-kr')

# %%
from kochat.data import Dataset


# 클래스 생성시 raw파일들을 검증하고 통합합니다.
dataset = Dataset(ood=False, naver_fix=True)  

# 임베딩 데이터셋 생성
embed_dataset = dataset.load_embed() 

# 인텐트 데이터셋 생성 (임베딩 프로세서 필요)
intent_dataset = dataset.load_intent(emb) 

# 엔티티 데이터셋 생성 (임베딩 프로세서 필요)
entity_dataset = dataset.load_entity(emb) 

# 추론용 데이터셋 생성 (임베딩 프로세서 필요)
predict_dataset = dataset.load_predict("원피스 추천해줘", emb)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-73b0e2982a0e> in <module>
# ----> 1 from kochat.data import Dataset
#       2
#       3
#       4 # 클래스 생성시 raw파일들을 검증하고 통합합니다.
#       5 dataset = Dataset(ood=False, naver_fix=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\kochat\data\__init__.py in <module>
# ----> 1 from kochat.data.dataset import Dataset
#       2
#       3 __ALL__ = [Dataset]
#
# C:\ProgramData\Anaconda3\lib\site-packages\kochat\data\dataset.py in <module>
#       9 from torch.utils.data import TensorDataset, DataLoader
#      10
# ---> 11 from kochat.data.organizer import Organizer
#      12 from kochat.data.preprocessor import Preprocessor
#      13 from kochat.decorators import data
#
# C:\ProgramData\Anaconda3\lib\site-packages\kochat\data\organizer.py in <module>
#       4 from pandas import DataFrame, Series
#       5
# ...
